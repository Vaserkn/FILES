# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
ratings = pd.read_csv('/home/vaserkn/VSCode/Anime_rec_sys/ratings.csv')

# %%
anime = pd.read_csv('/home/vaserkn/VSCode/Anime_rec_sys/anime.csv')
anime = anime.drop(columns=['Unnamed: 0'])

# %% [markdown]
# # Рекомендации на основе контента

# %% [markdown]
# ## Рекомендации на основе жанров

# %%
anime['Genres'] = anime['Genres'].astype(str)
genres = anime['Genres'].apply(lambda r: str(r.split(',')))

# %%
genres.iloc[0]
# Out:
# "['Action', ' Adventure', ' Comedy', ' Drama', ' Sci-Fi', ' Space']"

# %%
tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1, 2), min_df=0.0)
tfidf_matrix = tfidf.fit_transform(genres)

# %%
tfidf_matrix.shape
# Out:
# (17562, 973)

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
indices = pd.Series(anime.index, index=anime['Name'])

# %%
def get_recommendation(title):
    idx = indices[title]  # Находим индекс в данных по названию
    sim_scores = list(enumerate(cosine_sim[idx]))  # Создаём лист с индексам и коэфф. схожести между заданным и остальными аниме
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)  # Сортируем sim_scores
    sim_scores = sim_scores[1:11]  # Выбираем 10 самых похожих
    anime_indices = [i[0] for i in sim_scores]  # Сохраняем индексы
    return anime.iloc[anime_indices].drop(columns=['MAL_ID']).reset_index(drop=True) # Возвращаем фильмы соответствующие индексам

# %%
get_recommendation('Overlord')
# Out:
#                                                Name  Score  \
# 0                                 Ku Pao Ying Xiong   5.69
# 1                             Ys IV: The Dawn of Ys   5.79
# 2                   Sword Art Online II: Debriefing   6.56
# 3                         Valhait Rising: Kandou e.   5.61
# 4                      The Movie: Sekai no Mukou ni   7.14
# 5                                         Rara Maji   5.91
# 6                                     Mashiro Witch   5.50
# 7                                      Juuni Kokuki   8.06
# 8  Hajimari no Boukensha-tachi: Legend of Crystania   6.06
# 9                               Legend of Crystania   6.02
#
#                                               Genres     Type  Episodes  \
# 0            Action, Adventure, Fantasy, Game, Magic       TV      26.0
# 1                   Action, Adventure, Fantasy, Game  Special       1.0
# 2                   Action, Adventure, Fantasy, Game  Special       1.0
# 3                   Action, Adventure, Fantasy, Game      ONA       1.0
# 4  Action, Adventure, Fantasy, Game, Magic, Myste...    Movie       1.0
# 5                        Fantasy, Game, Magic, Music      ONA       1.0
# 6                                        Game, Magic      ONA       1.0
# 7    Action, Adventure, Fantasy, Magic, Supernatural       TV      45.0
# 8    Action, Adventure, Fantasy, Magic, Supernatural    Movie       1.0
# 9    Action, Adventure, Fantasy, Magic, Supernatural      OVA       3.0
#
#                           Aired         Duration  \
# 0   Sep 2, 2017 to Feb 17, 2018  14 min. per ep.
# 1                          1993           3 min.
# 2                  Oct 11, 2014          24 min.
# 3                   Jul 6, 2016           2 min.
# 4                  Jan 21, 2012    1 hr. 50 min.
# 5                  Jan 27, 2017           1 min.
# 6                  Mar 14, 2017           2 min.
# 7   Apr 9, 2002 to Aug 30, 2003  25 min. per ep.
# 8                  Jul 29, 1995    1 hr. 20 min.
# 9  Nov 21, 1996 to Apr 23, 1997  45 min. per ep.
#
#                            Rating  Popularity   Members  Favorites
# 0                             NaN      7613.0    3271.0        6.0
# 1       PG-13 - Teens 13 or older     11649.0     605.0        0.0
# 2       PG-13 - Teens 13 or older      1547.0   89257.0      363.0
# 3                    G - All Ages     14836.0     206.0        0.0
# 4       PG-13 - Teens 13 or older      4028.0   16190.0       26.0
# 5                    G - All Ages     11984.0     531.0        0.0
# 6       PG-13 - Teens 13 or older     14375.0     235.0        0.0
# 7       PG-13 - Teens 13 or older      1266.0  113627.0     2261.0
# 8       PG-13 - Teens 13 or older      6829.0    4391.0        6.0
# 9  R - 17+ (violence & profanity)      6909.0    4242.0        6.0

# %% [markdown]
# #### Рекомендации на основе всех имеющихся текстовых данных

# %%
soup = anime['Genres'] + anime['Type'] + anime['Rating']
soup = soup.astype(str)

# %%
soup.iloc[0]
# Out:
# 'Action, Adventure, Comedy, Drama, Sci-Fi, SpaceTVR - 17+ (violence & profanity)'

# %%
soup = soup.apply(lambda x: str.lower(x.replace(' ', '')))

# %%
soup = soup.apply(lambda x: ' '.join(x))

# %%
soup.iloc[0]
# Out:
# 'action,adventure,comedy,drama,sci-fi,spacetvr-17+(violence&profanity)'

# %%
count = CountVectorizer(analyzer='word',ngram_range=(1, 2),min_df=0.0, stop_words='english')
count_matrix = count.fit_transform(soup)

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)

# %%
get_recommendation('Overlord')
# Out:
#                                                 Name  Score  \
# 0                                       Overlord III   7.95
# 1             Fate/stay night: Unlimited Blade Works   8.22
# 2  Fate/stay night: Unlimited Blade Works 2nd Season   8.33
# 3                               Dororo to Hyakkimaru   7.17
# 4                                Legend of Crystania   6.02
# 5        Densetsu no Yuusha no Densetsu: Iris Report   6.55
# 6                              Garo: Honoo no Kokuin   7.41
# 7                                       Blade & Soul   6.09
# 8         Gate: Jieitai Kanochi nite, Kaku Tatakaeri   7.74
# 9        Nejimaki Seirei Senki: Tenkyou no Alderamin   7.73
#
#                                             Genres     Type  Episodes  \
# 0       Action, Magic, Fantasy, Game, Supernatural       TV      13.0
# 1             Action, Fantasy, Magic, Supernatural       TV      12.0
# 2             Action, Fantasy, Magic, Supernatural       TV      13.0
# 3                  Action, Adventure, Supernatural       TV      26.0
# 4  Action, Adventure, Fantasy, Magic, Supernatural      OVA       3.0
# 5       Action, Adventure, Fantasy, Magic, Shounen  Special       1.0
# 6     Action, Demons, Fantasy, Magic, Supernatural       TV      24.0
# 7         Action, Adventure, Fantasy, Martial Arts       TV      13.0
# 8             Action, Adventure, Fantasy, Military       TV      12.0
# 9             Action, Adventure, Fantasy, Military       TV      13.0
#
#                           Aired         Duration  \
# 0   Jul 10, 2018 to Oct 2, 2018  23 min. per ep.
# 1  Oct 12, 2014 to Dec 28, 2014  28 min. per ep.
# 2   Apr 5, 2015 to Jun 28, 2015  23 min. per ep.
# 3   Apr 6, 1969 to Sep 28, 1969  26 min. per ep.
# 4  Nov 21, 1996 to Apr 23, 1997  45 min. per ep.
# 5                  Oct 14, 2010          23 min.
# 6   Oct 4, 2014 to Mar 28, 2015  24 min. per ep.
# 7   Apr 4, 2014 to Jun 27, 2014  24 min. per ep.
# 8   Jul 4, 2015 to Sep 19, 2015  23 min. per ep.
# 9    Jul 9, 2016 to Oct 1, 2016  23 min. per ep.
#
#                            Rating  Popularity   Members  Favorites
# 0  R - 17+ (violence & profanity)       205.0  549484.0     4115.0
# 1  R - 17+ (violence & profanity)       119.0  742718.0    12756.0
# 2  R - 17+ (violence & profanity)       175.0  605173.0     7133.0
# 3  R - 17+ (violence & profanity)      4568.0   11954.0       76.0
# 4  R - 17+ (violence & profanity)      6909.0    4242.0        6.0
# 5  R - 17+ (violence & profanity)      3895.0   17411.0       22.0
# 6  R - 17+ (violence & profanity)      1222.0  120332.0      416.0
# 7  R - 17+ (violence & profanity)      1299.0  109933.0      137.0
# 8  R - 17+ (violence & profanity)       177.0  601037.0     5306.0
# 9  R - 17+ (violence & profanity)       589.0  245963.0     1225.0

# %% [markdown]
# #### Рекомендации на основе текстовых данных с учётом рейтинга и популярности

# %%
def filter_anime(prm, anime):
    col = prm[0]
    th = prm[1]
    if th == 'High':
        anime = anime.loc[anime[col] >= anime[col].quantile(0.75)]  # Находим аниме с значением >= 75% всех значений  в колонке
    elif th == 'Medium':
        anime = anime.loc[anime[col] >= anime[col].quantile(0.5)]  # Находим аниме с значением >= 50% всех значений  в колонке
    elif th == 'Low':
        anime = anime.loc[anime[col] >= anime[col].quantile(0.25)]  # Находим аниме с значением >= 25% всех значений  в колонке
    return anime  # Возвращаем отфильтрованный список

# %%
def get_filtered_rec(title, params=[('Score', 'High'), ('Popularity', 'Medium')]):
    idx = indices[title]  # Находим индекс в данных по названию
    sim_scores = list(enumerate(cosine_sim[idx]))  # Создаём лист с индексам и коэфф. схожести между заданным и остальными аниме
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)  # Сортируем sim_scores
    sim_scores = sim_scores[1:100]  # Выбираем 10 самых похожих
    anime_indices = [i[0] for i in sim_scores]  # Сохраняем индексы

    y = anime.iloc[anime_indices]  # Находим аниме по индексу

    for prm in params:
        y = filter_anime(prm, y)
    return y.drop(columns='MAL_ID').reset_index(drop=True)

# %%
get_filtered_rec('Death Note')
# Out:
#                                                  Name  Score  \
# 0                                 Death Note: Rewrite   7.71
# 1                        Kindaichi Shounen no Jikenbo   7.98
# 2                                          Id:Invaded   7.90
# 3                       Higurashi no Naku Koro ni Kai   8.23
# 4                                 Yuukoku no Moriarty   7.97
# 5                                      Shiki Specials   7.81
# 6                                 Beastars 2nd Season   8.06
# 7   Koukaku Kidoutai: Stand Alone Complex - The La...   8.10
# 8                                             Jin-Rou   7.79
# 9                        Kuroshitsuji: Book of Circus   8.13
